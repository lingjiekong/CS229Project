# %%
# load all data
import pandas as pd
import numpy as np
trainLoad = pd.read_csv("clicks_train.csv")
testLoad = pd.read_csv("clicks_test.csv")

# %%
# load promotedContent
promotedContent = pd.read_csv("promoted_content.csv")

# %%
# get portion of train and test from train_clicks
train = trainLoad[0:10001]
test = trainLoad[10001:10001+1000]

# %%
# make dictionary for train and test which make ad_id to click
lenTrain = len(train)
lenTest = len(test)
ad2ClickTrain = dict()
ad2ClickTest = dict()
# for train data
for i in range(lenTrain):
    adID = train.loc[i]["ad_id"]
    clickID = train.loc[i]["clicked"]
    if adID not in ad2ClickTrain:
        ad2ClickTrain[adID] = clickID
    else:
        ad2ClickTrain[adID] += clickID

# for test data
for i in range(lenTest):
    adIDTest = test.loc[i+10001]["ad_id"]
    clickIDTest = test.loc[i+10001]["clicked"]
    if adIDTest not in ad2ClickTest:
        ad2ClickTest[adIDTest] = clickIDTest
    else:
        ad2ClickTest[adIDTest] += clickIDTest

# %%
# get dict from campaign_id and advertise_id ad_id(features)
totalLen = len(promotedContent)
ad2Adv = dict()
ad2Cam = dict()
for i in range(totalLen):
    adID = promotedContent.loc[i]["ad_id"]
    advID = promotedContent.loc[i]["advertiser_id"]
    camID = promotedContent.loc[i]["campaign_id"]
    ad2Adv[adID] = advID
    ad2Cam[adID] = camID

# %%
# make new dictionary on campaign_id and advertise_id which gets clicked
cam2Click = dict()
adv2Click = dict()
for each in ad2ClickTrain:
    adID = each
    adv = ad2Adv[adID]
    if adv not in adv2Click:
        adv2Click[adv] = ad2ClickTrain[adID]
    else:
        adv2Click[adv] += ad2ClickTrain[adID]
        
    cam = ad2Cam[adID]
    if cam not in cam2Click:
        cam2Click[cam] = ad2ClickTrain[adID]
    else:
        cam2Click[cam] += ad2ClickTrain[adID]

# %%
print len(cam2Click)
print len(adv2Click)
# Out:
# 2556
# 738

# %%
import operator
# get top 50 features for both adv and cam and create a feature theta dictionary for training later
topAdvFeature = dict(sorted(adv2Click.iteritems(), key=operator.itemgetter(1), reverse=True)[:738])
topCamFeature = dict(sorted(cam2Click.iteritems(), key=operator.itemgetter(1), reverse=True)[:2556])
# print max(topCamFeature.values())
# print max(topAdvFeature.values())
thetaAdvDict = dict()
thetaCamDict = dict()
topAdvFeatureKeys = topAdvFeature.keys()
topCamFeatureKeys = topCamFeature.keys()
for i in range(len(topAdvFeatureKeys)):
    thetaAdvDict[topAdvFeatureKeys[i]] = 0
for i in range(len(topCamFeatureKeys)):
    thetaCamDict[topCamFeatureKeys[i]] = 0

# %%
# implement SVM based on selected top 50 features
totalItr = 5
trainLen = len(train)
eta = 0.1 # step size
for itr in range(totalItr):
    for i in range(trainLen):
        y = train.loc[i]["clicked"] # clicked is 1, else is 0
        # use y = 1 and -1 to run logistic regression
        if y == 0:
            y = -1
        adID = train.loc[i]['ad_id']
        adv = ad2Adv[adID]
        cam = ad2Cam[adID]
        
        # update thetaAdvDict for adv, x is 1 which is indicator of feature
        if adv in topAdvFeature:
            if 1-y*thetaAdvDict[adv]*1 > 0:
                JDerivative = -y*1
            else:
                JDerivative = 0
            thetaAdvDict[adv] -= eta*JDerivative
        # update thetaCamDict for cam
        if cam in topCamFeature:
            if 1-y*thetaCamDict[cam]*1 > 0:
                JDerivative = -y*1
            else: 
                JDerivative = 0
            thetaCamDict[cam] -= eta*JDerivative

# %%
# five iteration result
print thetaAdvDict
print ''
print topAdvFeature
print ''
print thetaCamDict
print ''
print topCamFeature
# Out:
# {4: -1.0999999999999999, 5: -0.99999999999999989, 8: -1.0999999999999999, 2057: -1.0999999999999999, 13: -0.99999999999999989, 14: -0.99999999999999989, 15: -0.5, 16: -1.0999999999999999, 17: -0.99999999999999989, 18: -0.5, 19: -1.0999999999999999, 20: 0.5, 22: 0.0, 24: -1.0999999999999999, 26: -0.5, 27: -1.0999999999999999, 29: -1.0999999999999999, 2079: -1.0999999999999999, 34: -0.5, 36: -0.5, 38: 0.0, 1713: -1.0999999999999999, 2090: -1.0999999999999999, 2091: -0.5, 2092: 0.5, 45: -1.0999999999999999, 47: -1.0999999999999999, 53: -1.0999999999999999, 9: -0.9999999999999999, 2106: -1.0999999999999999, 2110: -1.0999999999999999, 2111: -1.0999999999999999, 2120: 0.99999999999999989, 75: -0.5, 2125: 0.0, 2061: -1.0999999999999999, 82: -0.99999999999999989, 83: -1.0999999999999999, 84: -0.5, 87: -1.0999999999999999, 90: 0.0, 91: -0.99999999999999989, 92: -1.0999999999999999, 95: 0.5, 2144: -0.5, 2146: -1.0999999999999999, 102: -1.0999999999999999, 2151: -1.0999999999999999, 2156: -0.99999999999999989, 110: 0.0, 112: -0.99999999999999989, 114: -0.5, 115: -0.9999999999999999, 2169: -1.0999999999999999, 122: -1.0999999999999999, 125: -0.5, 2174: -0.5, 2175: -0.9999999999999999, 2176: -1.0999999999999999, 2177: -1.0999999999999999, 2178: -1.0999999999999999, 2179: -0.99999999999999989, 2180: -0.5, 2181: -0.5, 2182: -1.0999999999999999, 136: -0.5, 141: -0.99999999999999989, 142: -1.0999999999999999, 144: -1.0999999999999999, 2193: 0.0, 150: -1.0999999999999999, 2200: -1.0999999999999999, 2201: 0.5, 155: -0.5, 162: -0.5, 2212: 0.0, 168: -0.5, 169: -1.0999999999999999, 171: -0.5, 172: -1.0999999999999999, 2418: -1.0999999999999999, 2222: -0.99999999999999989, 2223: -1.0999999999999999, 176: -1.0999999999999999, 177: 1.0999999999999999, 342: -0.5, 185: -1.0999999999999999, 2238: -1.0999999999999999, 2241: -1.0999999999999999, 2245: -1.0999999999999999, 2251: -1.0999999999999999, 210: -0.99999999999999989, 2264: -1.0999999999999999, 2266: 0.0, 2735: 0.5, 228: 0.5, 2277: 0.5, 232: -1.0999999999999999, 256: -0.99999999999999989, 2309: 0.0, 265: -1.0999999999999999, 266: -1.0999999999999999, 2093: -0.99999999999999989, 2323: 0.99999999999999989, 2325: -1.0999999999999999, 279: 0.0, 283: -1.0999999999999999, 285: -1.0999999999999999, 288: -0.99999999999999989, 2184: -1.0999999999999999, 295: -2.7755575615628914e-17, 296: 0.99999999999999989, 2348: -1.0999999999999999, 2349: -1.0999999999999999, 2351: 0.0, 2352: -1.0999999999999999, 305: -0.5, 308: -1.0999999999999999, 2360: 0.5, 314: -1.0999999999999999, 318: -0.5, 2372: -0.99999999999999989, 2373: 0.0, 2380: 0.89999999999999991, 2381: -1.0999999999999999, 336: -0.89999999999999991, 2390: 0.5, 2391: -1.0999999999999999, 350: -1.0999999999999999, 352: -1.0999999999999999, 2407: -1.0999999999999999, 2413: -0.5, 367: 0.0, 368: -0.5, 370: -1.0999999999999999, 372: -1.0999999999999999, 377: -0.99999999999999989, 2426: -0.5, 380: -1.0999999999999999, 2429: -0.99999999999999989, 394: -0.99999999999999989, 2447: -1.0999999999999999, 402: -1.0999999999999999, 1309: -1.0999999999999999, 407: -1.0999999999999999, 415: -0.99999999999999989, 419: -0.99999999999999989, 425: -1.0999999999999999, 1378: -1.0999999999999999, 438: -0.5, 2804: -1.0999999999999999, 2493: -1.0999999999999999, 446: -1.0999999999999999, 450: 1.0999999999999999, 2506: -0.99999999999999989, 464: -0.5, 472: -1.0999999999999999, 473: -0.99999999999999989, 486: -0.5, 2812: 0.99999999999999989, 2546: -0.5, 505: -0.99999999999999989, 2555: -1.0999999999999999, 2556: -1.0999999999999999, 2557: -1.0999999999999999, 767: -0.5, 2563: -1.0999999999999999, 517: -1.0999999999999999, 2571: 0.5, 2579: -1.0999999999999999, 535: -1.0999999999999999, 2585: -0.99999999999999989, 2589: -1.0999999999999999, 549: 0.0, 551: -0.89999999999999991, 2600: -0.5, 554: 0.5, 2603: -0.99999999999999989, 557: -0.89999999999999991, 2609: 0.99999999999999989, 563: -0.5, 566: -0.99999999999999989, 2616: -1.0999999999999999, 2625: -1.0999999999999999, 579: -0.5, 580: - ...
#
# {4: 3, 5: 8, 8: 1, 2057: 9, 13: 3, 14: 1, 15: 0, 16: 8, 17: 4, 18: 0, 19: 4, 20: 1, 22: 1, 24: 8, 26: 1, 27: 3, 29: 1, 2079: 8, 34: 0, 36: 0, 38: 1, 2090: 4, 2091: 0, 2092: 1, 45: 6, 47: 1, 53: 6, 9: 0, 2106: 1, 2110: 2, 2111: 2, 2120: 3, 75: 0, 2125: 2, 2061: 0, 82: 1, 83: 8, 84: 1, 87: 2, 90: 2, 91: 1, 92: 10, 95: 1, 2144: 2, 2146: 8, 102: 5, 2151: 10, 2156: 4, 110: 1, 112: 4, 114: 0, 115: 0, 2169: 7, 122: 0, 125: 0, 2174: 0, 2175: 0, 2176: 2, 2177: 1, 2178: 5, 2179: 3, 2180: 6, 2181: 3, 2182: 4, 136: 1, 141: 6, 142: 4, 144: 5, 2193: 1, 150: 2, 2200: 7, 2201: 4, 155: 1, 162: 0, 2212: 1, 168: 4, 169: 0, 171: 0, 172: 2, 2418: 2, 2222: 12, 2223: 1, 176: 2, 177: 16, 342: 0, 185: 0, 2238: 7, 2241: 2, 2245: 2, 2251: 2, 210: 9, 2264: 1, 2266: 1, 2735: 1, 228: 1, 2277: 2, 232: 14, 622: 1, 256: 7, 2309: 1, 265: 1, 266: 3, 2093: 4, 2323: 7, 2325: 1, 279: 2, 283: 4, 285: 10, 288: 1, 2184: 0, 295: 12, 296: 7, 2348: 11, 2349: 4, 2351: 1, 2352: 6, 305: 1, 308: 3, 2360: 1, 314: 1, 318: 1, 2372: 2, 2373: 1, 2380: 8, 2381: 12, 336: 11, 2390: 1, 2391: 4, 350: 8, 352: 1, 2603: 5, 2407: 6, 2413: 3, 367: 1, 368: 1, 370: 1, 372: 9, 377: 5, 2426: 7, 380: 9, 2429: 1, 394: 16, 2447: 2, 402: 1, 968: 1, 407: 10, 415: 4, 419: 2, 425: 2, 2333: 0, 438: 1, 756: 1, 2493: 2, 446: 3, 450: 6, 2506: 1, 464: 2, 472: 3, 473: 2, 486: 6, 764: 4, 3426: 12, 2546: 1, 505: 5, 2555: 1, 2556: 4, 2557: 6, 2563: 1, 517: 5, 2571: 1, 2579: 1, 535: 8, 2585: 3, 2589: 3, 549: 1, 551: 6, 2600: 1, 554: 2, 555: 7, 557: 4, 2609: 6, 563: 10, 566: 3, 2616: 2, 2815: 1, 2625: 1, 579: 2, 580: 8, 2635: 9, 2636: 5, 2639: 5, 603: 2, 607: 1, 2656: 2, 613: 1, 617: 7, 2668: 11, 621: 5, 2670: 31, 628: 10, 629: 2, 2681: 1, 2690: 3, 2691: 21, 2694: 7, 2702: 3, 2840: 1, 2710: 2, 2711: 1, 2712: 5, 2713: 15, 2714: 1, 670: 1, 2721: 6, 2722: 12, 2727: 11, 681: 5, 685: 3, 687: 1, 689: 3, 2740: 1, 2741: 3, 696: 1, 2747: 5, 702: 1, 2754: 10, 2757: 1, 2762: 2, 718: 9, 2768: 9, 2769: 11, 725: 3, 726: 3, 2777: 3, 2783: 1, 744: 1, 752: 7, 2803: 1, 2804: 2, 2807: 3, 2808: 8, 761: 3, 2812: 6, 767: 1, 769: 6, 781: 2, 784: 5, 791: 1, 792: 3, 2844: 14, 797: 6, 799: 1, 2848: 3, 802: 2, 805: 1, 2862: 1, 2865: 5, 2869: 4, 2871: 12, 2874: 5, 2876: 15, 832: 6, 2909: 16, 862: 1, 865: 3, 2914: 1, 2917: 2, 2926: 2, 2927: 3, 891: 1, 2198: 1, 906: 2, 912: 2, 913: 4, 915: 2, 916: 11, 2976: 1, 2988: 5, 3001: 12, 3004: 1, 957: 2, 3016: 4, 977: 2, 3026: 4, 3037: 6, 992: 2, 994: 1, 1004: 1, 1006: 8, 1008: 3, 2216: 0, 1010: 6, 1016: 1, 1017: 1, 3074: 7, 3075: 1, 1028: 1, 1031: 15, 1032: 2, 3087: 1, 1043: 9, 3098: 3, 1051: 1, 3101: 1, 1055: 6, 1060: 4, 1061: 2, 1067: 3, 3119: 2, 1073: 1, 1074: 1, 1077: 1, 3126: 1, 1089: 6, 1095: 2, 1096: 1, 1099: 1, 1113: 1, 1114: 1, 3190: 6, 3195: 1, 3200: 15, 3211: 1, 1171: 4, 3220: 16, 1185: 6, 3236: 1, 3243: 5, 1197: 3, 1198: 19, 1199: 1, 3251: 8, 3253: 2, 1206: 11, 1214: 4, 1218: 2, 3267: 1, 1222: 6, 3273: 1, 3277: 3, 3279: 4, 3283: 9, 1258: 2, 2095: 1, 1268: 2, 1276: 1, 3330: 1, 1283: 1, 1286: 4, 1287: 1, 1289: 2, 1299: 1, 3351: 11, 3357: 2, 1310: 1, 1321: 6, 1352: 1, 1358: 1, 1367: 1, 1378: 8, 3429: 2, 1386: 3, 3448: 2, 3451: 1, 3463: 2, 1419: 1, 1429: 1, 3481: 1, 1434: 1, 1438: 5, 1439: 4, 1448: 2, 1450: 1, 1452: 3, 1453: 4, 1462: 9, 1465: 1, 1466: 2, 3529: 9, 1485: 3, 1486: 1, 3546: 2, 3548: 1, 1502: 3, 1509: 1, 1510: 12, 3801: 6, 1521: 4, 3570: 1, 1534: 1, 1539: 1, 1544: 3, 1554: 2, 1555: 4, 1559: 5, 1570: 7, 1575: 1, 1587: 1, 3337: 1, 1593: 11, 1594: 9, 3645: 2, 4021: 2, 1601: 2, 1607: 3, 1613: 1, 1617: 3, 1624: 1, 1625: 5, 1627: 9, 1634: 4, 1635: 5, 1636: 1, 1637: 1, 1644: 7, 1650: 5, 1656: 7, 3710: 10, 1665: 17, 3715: 1, 3718: 2, 4033: 1, 1672: 10, 1676: 4, 1677: 2, 2669: 1, 1683: 2, 1684: 4, 1685: 8, 1701: 4, 1703: 6, 3753: 3, 1309: 4, 1713: 7, 3763: 1, 1723: 0, 1724: 1, 1726: 3, 1731: 8, 1734: 1, 1752: 9, 1753: 9, 1754: 10, 3803: 3, 2718: 1, 1759: 4, 3813: 2, 1774: 6, 3829: 2, 1782: 19, 1783: 2, 1786: 1, 1791: 1, 1793: 1, 1797: 6, 1809: 7, 1810: 3, 1811: 1, 1813: 9, 1819: 1, 1820 ...
#
# {20481: -0.99999999999999989, 14329: 0.0, 4: -0.5, 6145: 0.5, 17622: -0.99999999999999989, 27308: 0.5, 12302: 0.0, 4781: -0.5, 2064: 0.5, 8210: -0.99999999999999989, 2067: -1.0999999999999999, 26324: -1.0999999999999999, 18454: 0.0, 30: -1.0999999999999999, 5125: -1.0999999999999999, 24608: 0.5, 18465: 1.0999999999999999, 19462: -0.5, 8232: -0.5, 5468: 0.5, 20523: 0.5, 20524: -0.99999999999999989, 8237: 0.0, 20528: 0.0, 18099: 0.0, 8245: 0.5, 20489: -1.0999999999999999, 18488: -1.0999999999999999, 2105: -1.0999999999999999, 6202: -1.0999999999999999, 22587: 0.5, 9359: 0.5, 20544: 0.0, 20545: -0.99999999999999989, 26690: -1.0999999999999999, 22597: 0.0, 6217: 0.0, 8267: -0.5, 4172: 0.5, 79: -1.0999999999999999, 22609: -0.5, 8274: 0.0, 20835: 0.5, 10324: -1.0999999999999999, 12374: -1.0999999999999999, 29028: 0.0, 6235: -0.99999999999999989, 28767: 0.5, 2146: 0.0, 29371: -0.99999999999999989, 10598: -0.99999999999999989, 20586: 0.0, 11623: 0.99999999999999989, 2157: -0.5, 4206: 0.5, 112: 0.5, 12401: 0.5, 22643: 2.7755575615628914e-17, 12404: -1.0999999999999999, 20597: 0.0, 10601: -1.0999999999999999, 120: -0.99999999999999989, 20601: 0.99999999999999989, 22650: 0.0, 10363: -0.99999999999999989, 8392: 0.5, 6269: 0.89999999999999991, 22655: 0.0, 2176: -1.0999999999999999, 18561: 1.0999999999999999, 6275: -1.0999999999999999, 6276: 0.0, 28806: 0.0, 28807: 0.99999999999999989, 28808: 0.0, 16235: -0.99999999999999989, 16528: -1.0999999999999999, 22674: -0.99999999999999989, 20627: -0.5, 12437: 0.0, 16535: 0.5, 6296: -1.0999999999999999, 18586: 0.0, 22684: -0.89999999999999991, 157: -1.0999999999999999, 22686: -0.5, 14496: -1.0999999999999999, 24737: 0.99999999999999989, 13167: -1.0999999999999999, 169: -0.5, 20651: 0.5, 6316: -1.0999999999999999, 18605: -1.0999999999999999, 18608: -1.0999999999999999, 2226: 0.0, 11635: 0.0, 12468: -1.0999999999999999, 5833: -0.89999999999999991, 9588: -0.5, 16573: -1.0999999999999999, 21877: 0.5, 22720: 0.5, 7978: -1.0999999999999999, 2422: -0.99999999999999989, 18630: -0.5, 20679: 0.5, 16584: 0.5, 6345: 0.5, 23245: 0.0, 8568: 0.0, 14546: 0.99999999999999989, 26836: 0.0, 14549: 0.0, 22742: 0.0, 28025: -1.0999999999999999, 2264: -0.5, 3826: 0.0, 13578: -0.5, 24796: -1.0999999999999999, 28893: -1.0999999999999999, 20702: 0.0, 8415: 0.5, 16610: -0.99999999999999989, 12515: 0.5, 22757: 0.0, 20712: -0.5, 24811: 0.5, 18668: -1.0999999999999999, 14574: 0.99999999999999989, 14717: -0.99999999999999989, 22768: 0.99999999999999989, 9939: 0.5, 8436: 0.5, 245: -1.0999999999999999, 24822: 0.99999999999999989, 25641: -1.0999999999999999, 249: -1.0999999999999999, 4346: -1.0999999999999999, 6395: 0.5, 16636: -1.0999999999999999, 4353: 0.5, 10498: -1.0999999999999999, 6405: -1.0999999999999999, 16648: 0.0, 9260: 0.0, 10967: 0.5, 26892: 0.5, 22797: 0.5, 24847: 0.5, 22807: 0.0, 10523: -1.0999999999999999, 24860: 0.5, 10525: 0.0, 13701: 0.99999999999999989, 22821: -0.99999999999999989, 24901: 0.5, 4392: -0.5, 10537: 0.5, 10542: -0.99999999999999989, 14641: 0.0, 14642: -1.0999999999999999, 29266: 0.0, 20790: 0.5, 12599: 0.99999999999999989, 12600: -0.99999999999999989, 24890: 0.0, 22843: -1.0999999999999999, 14652: 0.5, 11367: -0.99999999999999989, 20802: -0.99999999999999989, 129: -0.5, 26949: -1.0999999999999999, 24902: 1.0999999999999999, 4423: -0.99999999999999989, 24906: 0.0, 333: 0.5, 5517: -1.0999999999999999, 8528: -0.5, 6200: -1.0999999999999999, 20819: -0.99999999999999989, 6488: 0.0, 12638: -0.5, 10591: -1.0999999999999999, 4449: 0.0, 4451: -1.0999999999999999, 356: -1.0999999999999999, 18789: 0.5, 4454: 1.0999999999999999, 2535: 0.5, 29032: -1.0999999999999999, 26985: 0.5, 2410: 0.0, 22891: -1.0999999999999999, 14702: 0.0, 22896: 0.5, 20851: 0.5, 16756: 0.5, 373: -0.5, 29046: -1.0999999999999999, 29048: -0.5, 10621: 1.0999999999999999, 12672: -1.0999999999999999, 18817: 0.5, 12675: 0.5, 14402: 0.0, 27030: 0.5, 12678: 0.5, 65: 0.0, 4488: -1.0999999999999999, 20877: 0.0, 6544: -1.0999999999999999, 12689: 0.0, ...
#
# {20481: 1, 4: 1, 6145: 1, 12972: 1, 14594: 1, 12302: 1, 27309: 5, 2064: 1, 8210: 1, 2067: 1, 18454: 1, 16047: 1, 30: 3, 23557: 1, 24608: 1, 18465: 4, 6275: 1, 27654: 1, 8232: 1, 7516: 1, 20523: 1, 20524: 1, 8237: 1, 20528: 1, 11955: 1, 8245: 1, 27657: 1, 18488: 16, 2105: 1, 6202: 2, 22587: 1, 20544: 2, 20545: 2, 26690: 1, 22597: 1, 9569: 1, 6217: 2, 8267: 3, 4172: 1, 29447: 1, 79: 2, 22609: 4, 8274: 1, 20835: 1, 10324: 2, 12374: 1, 29028: 1, 6235: 6, 1094: 1, 13669: 2, 2146: 1, 17083: 1, 10598: 1, 20586: 2, 1383: 4, 2157: 1, 4206: 1, 112: 1, 12401: 1, 22643: 5, 12404: 1, 20597: 2, 10601: 6, 120: 2, 20601: 2, 22650: 1, 10363: 3, 6269: 6, 22655: 1, 2176: 2, 18561: 16, 16515: 1, 6276: 1, 28806: 1, 28807: 2, 28808: 1, 16528: 3, 22674: 2, 20627: 3, 12437: 3, 16535: 1, 6296: 6, 18586: 1, 22684: 2, 157: 4, 22686: 1, 14496: 2, 24737: 10, 169: 2, 20651: 1, 6316: 1, 18605: 2, 18608: 1, 2226: 1, 15731: 2, 12468: 1, 1737: 1, 11636: 1, 16573: 1, 22720: 1, 2422: 1, 18630: 1, 20679: 1, 200: 2, 6345: 1, 10957: 4, 8568: 1, 14546: 2, 26836: 2, 14549: 3, 22742: 2, 25977: 1, 2264: 1, 24796: 2, 1402: 1, 20702: 2, 8415: 1, 4781: 1, 16610: 4, 12515: 1, 22757: 1, 20712: 1, 24811: 1, 18668: 1, 14574: 2, 14717: 1, 22768: 3, 14035: 1, 8436: 1, 245: 13, 24822: 5, 9257: 1, 249: 2, 4346: 2, 6395: 6, 16636: 9, 4353: 1, 10498: 3, 6405: 1, 16648: 2, 27692: 1, 10967: 1, 26892: 1, 22797: 1, 24847: 1, 21891: 1, 12898: 1, 22807: 1, 15626: 1, 10523: 1, 24860: 1, 10525: 1, 17797: 1, 15215: 1, 22821: 3, 15032: 1, 4392: 2, 10537: 1, 10542: 1, 14641: 2, 14642: 2, 20790: 1, 12599: 3, 12600: 1, 24890: 1, 22843: 8, 14652: 1, 4716: 1, 20802: 2, 26949: 2, 24902: 6, 4423: 2, 24906: 2, 333: 1, 25997: 1, 8528: 2, 6200: 1, 20819: 1, 9354: 1, 6488: 1, 4062: 1, 12638: 1, 10591: 1, 4449: 1, 4451: 1, 356: 1, 18789: 2, 4454: 5, 29032: 2, 26985: 2, 2410: 1, 22891: 1, 7570: 1, 14702: 6, 28767: 1, 22896: 1, 20851: 1, 16756: 1, 373: 4, 29046: 3, 29048: 3, 16584: 1, 10621: 6, 12672: 1, 18817: 1, 12675: 1, 14402: 1, 27030: 1, 12678: 6, 65: 1, 4488: 1, 3479: 1, 20877: 3, 6544: 8, 12689: 2, 14739: 1, 14742: 16, 4504: 1, 14746: 2, 10651: 1, 2460: 1, 20895: 1, 4512: 1, 20897: 3, 21359: 1, 22382: 3, 27046: 1, 16808: 2, 4508: 1, 25005: 4, 2478: 1, 18863: 1, 25012: 12, 10678: 1, 2489: 2, 25018: 1, 25020: 2, 2496: 2, 25027: 1, 14753: 2, 22984: 1, 20943: 2, 29432: 1, 18901: 1, 13566: 1, 21241: 1, 29144: 1, 25049: 1, 25051: 1, 4572: 1, 15099: 1, 8273: 1, 6632: 2, 20969: 1, 490: 1, 491: 1, 16876: 1, 2541: 1, 25070: 2, 20975: 3, 2544: 1, 4593: 3, 10740: 2, 20984: 1, 12795: 1, 20993: 3, 515: 1, 12804: 1, 12806: 1, 2568: 1, 18954: 1, 2573: 1, 22957: 1, 29201: 1, 4723: 1, 27157: 2, 21015: 1, 15430: 1, 16925: 6, 543: 1, 2592: 1, 16931: 1, 27173: 1, 10790: 2, 4647: 1, 8746: 4, 26410: 1, 8748: 6, 8749: 1, 16942: 1, 564: 2, 565: 1, 2615: 1, 14772: 1, 10335: 1, 21053: 1, 21056: 1, 4673: 5, 29250: 2, 14916: 1, 14774: 1, 21062: 3, 21063: 2, 25160: 3, 8784: 3, 23122: 3, 19128: 1, 25174: 5, 20921: 1, 19032: 1, 23131: 2, 19038: 1, 14943: 1, 10850: 1, 21091: 3, 6756: 2, 6757: 3, 21948: 1, 6763: 3, 2668: 3, 14961: 1, 10866: 2, 23480: 1, 17012: 2, 2679: 1, 4732: 1, 14442: 1, 1726: 1, 6784: 3, 6787: 2, 19077: 1, 25222: 3, 17033: 3, 6797: 2, 22637: 1, 22638: 1, 21143: 14, 4932: 1, 6871: 1, 29340: 10, 21149: 1, 15010: 2, 15013: 1, 678: 1, 12775: 1, 19115: 3, 27308: 2, 25261: 3, 10926: 1, 12975: 1, 5342: 1, 12978: 2, 2163: 2, 4789: 1, 17080: 2, 29371: 2, 10945: 1, 4803: 1, 23237: 1, 27334: 4, 11041: 1, 11493: 1, 23245: 4, 15054: 1, 27343: 1, 15059: 2, 724: 5, 28793: 2, 21227: 1, 10969: 1, 21210: 11, 10974: 3, 2783: 1, 24699: 1, 21220: 1, 20262: 1, 15079: 1, 28455: 1, 749: 1, 6894: 1, 751: 2, 10616: 1, 20264: 1, 17138: 1, 21238: 1, 21239: 1, 2808: 1, 4857: 1, 17146: 4, 27387: 1, 21244: 3, 21245: 2, 24704: 1, 17156: 1, 17158: 5, 17159: 3, 23309: 1, 15118: 1, 6929: 1, 5959: 1, 7299: 1, 11037: 1, 25375: 1, 25376: 1, 19233: 6, 20955: 1, 2854: 1, 12984: 3, 4909: 1, 4910: 1, 4911: 1, 6960: 2, 21302: 1, 4919: 2, 18031: 1, 1311 ...

# %%
# make prediction
from copy import deepcopy
import random
testResult = deepcopy(test)
testLen = len(testResult)
for i in range(0,testLen):
    testResult.set_value(i+10001, 'clicked', 0)
    
displayID = testResult.loc[10001+0]["display_id"]
maxHypo = 0
maxset = []

tie = 0

for i in range(0,testLen):
    if displayID == testResult.loc[10001+i]["display_id"]:
        # the same displayID
        adID = testResult.loc[10001+i]['ad_id']
        adv = ad2Adv[adID]
        cam = ad2Cam[adID]
        if adv in thetaAdvDict:
            thetaAdv = thetaAdvDict[adv]
            hypoAdv = 1-y*thetaAdvDict[adv]*1
        else:
            hypoAdv = 0
        if cam in thetaCamDict:
            thetaCam = thetaCamDict[cam]
            hypoCam = 1-y*thetaCamDict[cam]*1
        else:
            hypoCam = 0
        Hypo = hypoAdv + hypoCam
        Hpyo = max(0, Hypo)
        if Hypo > maxHypo:
            maxHypo = Hypo
            maxset = []
            maxset.append((10001+i, adID))
        elif Hypo == maxHypo:
            maxset.append((10001+i, adID))
    else:
        # make prediction
        if len(maxset) == 1:
            maxvalue = maxset[0]
            index = maxvalue[0]
        else:
            tie += 1
            maxvalue = random.sample(maxset, 1)
            index = maxvalue[0][0]
        testResult.set_value(index, 'clicked', 1)
        # Start the next
        maxHypo = 0
        adID = testResult.loc[10001+i]['ad_id']
        adv = ad2Adv[adID]
        cam = ad2Cam[adID]
        if adv in thetaAdvDict:
            thetaAdv = thetaAdvDict[adv]
            hypoAdv = 1-y*thetaAdvDict[adv]*1
        else:
            hypoAdv = 0
        if cam in thetaCamDict:
            thetaCam = thetaCamDict[cam]
            hypoCam = 1-y*thetaCamDict[cam]*1
        else:
            hypoCam = 0
        maxHypo = hypoAdv + hypoCam
        maxHpyo = max(0, Hypo)
        maxset = []
        maxset.append((10001+i, adID))
        displayID = testResult.loc[10001+i]["display_id"]
            
    if i == testLen-1:
        if len(maxset) == 1:
            maxvalue = maxset[0]
            index = maxvalue[0]
        else:
            maxvalue = random.sample(maxset, 1)
            index = maxvalue[0][0]
        testResult.set_value(index, 'clicked', 1)

# %%
# print out percenrage
displayID = testResult.loc[10001+0]["display_id"]
totalCount = 0
count = 0
for i in range(testLen):
    if testResult.loc[10001+i]["clicked"] == test.loc[10001+i]["clicked"] and test.loc[10001+i]["clicked"] == 1:
        count += 1
    if displayID != testResult.loc[10001+i]["display_id"]:
        totalCount += 1
        displayID = testResult.loc[10001+i]["display_id"]
print float(count)/float(totalCount)
# Out:
# 0.439393939394
